# %%
import numpy as np
import matplotlib.pyplot as plt
import json

class data_storage:
    b = np.array([]);
    l = np.array([]);
    t = np.array([]);
    v = np.array([]);
    d = np.array([]);
    g = np.array([]);
    s = np.array([]);
    c = np.array([]);

def extract_data( TXTpath ):
    X = data_storage()
    Cb = 0;
    Ct = 0;
    with open(TXTpath) as f:
        line = f.readline()
        while line:
            line = f.readline()
            if( line[0:2] == ".b" ):
                Cb+=1;
                X.b = np.append(X.b, int(line[2:]))
            if( line[0:2] == ".g" ):
                X.g = np.append(X.g, int(line[3:]))        
            if( line[0:2] == ".s" ):
                X.s = np.append(X.s, int(line[3:]))
            if( line[0:2] == ".c" ):
                X.c = np.append(X.c, float(line[3:]))
            if( line[0:2] == ".d" ):
                X.d = np.append(X.d, int(line[3:]))
            if( line[0:2] == ".l" ):
                X.l = np.append(X.l,float(line[3:]))
            if( line[0:2] == ".t" ):
                Ct+=1;
                X.t = np.append(X.t,float(line[3:]))
                if( Cb != Ct ):
                    print(X.b[Cb-1])
            if( line[0:2] == ".v" ):
                X.v = np.append(X.v,float(line[3:]))
            
    return X
    


SD = extract_data( 'SD/RES/summary.txt' )
ISD = extract_data( 'ISD/RES/summary.txt' )
IDSD = extract_data( 'IDSD/RES/summary.txt' )
IDSD0 = extract_data( 'IDSD0/RES/summary.txt' )
IDSD1 = extract_data( 'IDSD1/RES/summary.txt' )
IDSD2 = extract_data( 'IDSD2/RES/summary.txt' )
IDSD3 = extract_data( 'IDSD3/RES/summary.txt' )
IDSDopt = extract_data( 'IDSDopt/RES/summary.txt' )
IDSDadv = extract_data( 'IDSDadv/RES/summary.txt' )
aIDSD = extract_data( 'aIDSD/RES/summary.txt' )
tIDSD = extract_data( 'tIDSD/RES/summary.txt' )
fIDSD = extract_data( 'fIDSD/RES/summary.txt' )
dcIDSD = extract_data( 'dcIDSD/RES/summary.txt' )

f = open ('../SD.json', "r")
SDjson = json.loads(f.read())

f = open ('../ISD.json', "r")
ISDjson = json.loads(f.read())

f = open ('../IDSD.json', "r")
IDSDjson = json.loads(f.read())

f = open ('../IDSDopt.json', "r")
IDSDoptjson = json.loads(f.read())

f = open ('../IDSDadv.json', "r")
IDSDadvjson = json.loads(f.read())

f = open ('../IDSD0.json', "r")
IDSD0json = json.loads(f.read())

f = open ('../IDSD1.json', "r")
IDSD1json = json.loads(f.read())

f = open ('../IDSD2.json', "r")
IDSD2json = json.loads(f.read())

f = open ('../IDSD3.json', "r")
IDSD3json = json.loads(f.read())

f = open ('../dcIDSD.json', "r")
dcIDSDjson = json.loads(f.read())

f = open ('../aIDSD.json', "r")
aIDSDjson = json.loads(f.read())
f.close()

f = open ('../tIDSD.json', "r")
tIDSDjson = json.loads(f.read())

f = open ('../fIDSD.json', "r")
fIDSDjson = json.loads(f.read())

runtimeSD = [SDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeISD = [ISDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSD = [IDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSDopt = [IDSDoptjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#runtimeIDSDadv = [IDSDadvjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimedcIDSD = [dcIDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeaIDSD = [aIDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSD0 = [IDSD0json[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSD1 = [IDSD1json[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSD2 = [IDSD2json[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimeIDSD3 = [IDSD3json[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimetIDSD = [tIDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]
runtimefIDSD = [fIDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]

# %%
#import matplotlib.font_manager

fig = plt.figure(figsize=(17,6))
ax = plt.gca()
plt.xticks(range(0,100,5), fontsize=30)
for b in range(0,100,1):
    plt.axvline(x=b, color='k', alpha = 0.3)
for b in range(0,100,5):
    plt.axvline(x=b, color='k', alpha = 0.5)
plt.grid()
line0, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
line1, = ax.plot(ISD.b, ISD.t , 'D', c='k', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
line2, = ax.plot(IDSD.b, IDSD.t, 'o', c='yellow', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
line3, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='red', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')

ax.legend( handles = [line0,line1,line3, line2], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,

plt.rcParams["font.family"] = "sans"
plt.xlabel('Benchmark', fontsize=35)
plt.ylabel('Accuracy[%]', fontsize=35)
plt.title('Test Accuracy', fontsize=45)
ax.tick_params(axis='both', which='major', labelsize=12)
plt.savefig('acc.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-7a97690345ca> in <module>
#      11 line0, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#      12 line1, = ax.plot(ISD.b, ISD.t , 'D', c='k', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
# ---> 13 line2, = ax.plot(IDSD.b, IDSD.t, 'o', c='yellow', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
#      14 line3, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='red', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
#      15
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
#import matplotlib.font_manager

fig = plt.figure(figsize=(17,6))
ax = plt.gca()
plt.xticks(range(0,100,5), fontsize=30)
for b in range(0,100,1):
    plt.axvline(x=b, color='k', alpha = 0.3)
plt.grid()

line1, = ax.plot(tIDSD.b, tIDSD.t , 'D', c='k', alpha=1, markeredgecolor='k', markersize = 18 , label = 'tIDSD')
line2, = ax.plot(IDSD.b, IDSD.t, 'o', c='yellow', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
line3, = ax.plot(aIDSD.b, aIDSD.t, 'P', c='red', alpha=1, markeredgecolor='k', markersize = 13, label = 'aDSD')

ax.legend( handles = [line1,line3, line2], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,

plt.rcParams["font.family"] = "sans"

plt.xlabel('Benchmark', fontsize=35)
plt.ylabel('Accuracy[%]', fontsize=35)
plt.title('Test Accuracy', fontsize=45)
ax.tick_params(axis='both', which='major', labelsize=12)
plt.savefig('acc.png')

# %%
from tabulate import tabulate
def extract_row_data( X, runtime, label ):
    return [label, np.mean(X.l),np.mean(X.t), np.mean(X.g), np.mean(X.d), np.mean(X.v-X.t), np.mean(runtime)]

row0 = extract_row_data( SD, runtimeSD, "SD")
row1 = extract_row_data( ISD, runtimeISD,"ISD" )
row2 = extract_row_data( tIDSD, runtimetIDSD, "tIDSD" )
row3 = extract_row_data( IDSD, runtimeIDSD,"dkIDSD" )
row3b = extract_row_data( fIDSD, runtimefIDSD, "fIDSD" )
row4 = extract_row_data( aIDSD, runtimeaIDSD, "aIDSD" )
row5 = extract_row_data( dcIDSD, runtimedcIDSD, "dcIDSD" )
row6 = extract_row_data( IDSDopt, runtimeIDSDopt, "IDSDopt" )
row7 = extract_row_data( IDSDadv, runtimeIDSDopt, "IDSDadv" )
row8 = extract_row_data( IDSD0, runtimeIDSD0, "IDSD0" )
row9 = extract_row_data( IDSD1, runtimeIDSD1, "IDSD1" )
row10 = extract_row_data( IDSD2, runtimeIDSD2, "IDSD2" )
row10 = extract_row_data( IDSD2, runtimeIDSD1, "IDSD3" )

#row2 = ["I-DSD",np.mean(t2), np.mean(g2), np.mean(s2), np.mean(d2), np.mean(np.abs(t2-v2))];
table = [ row0, row1, row2, row3, row3b, row6, row4, row5, row7, row8, row9,row10 ] #row2
print(tabulate(table, headers = ["method","train accuracy","test accuracy","And gates","levels","overfit","time"], tablefmt="github"))
# Out:
# | method   |   train accuracy |   test accuracy |   And gates |   levels |   overfit |     time |
# |----------|------------------|-----------------|-------------|----------|-----------|----------|
# | SD       |          99.9966 |         64.9619 |     6189.64 |   140.61 |  0.144843 |  6.59064 |
# | ISD      |          99.9966 |         80.4341 |     1162.23 |    72.54 |  0.17734  |  3.32478 |
# | tIDSD    |          99.9966 |         80.9163 |      957.27 |    68.97 |  0.170778 |  5.39861 |
# | dkIDSD   |          99.9966 |         81.0314 |      951.04 |    68.96 |  0.181558 | 18.7621  |
# | fIDSD    |          99.9966 |         80.9163 |      957.27 |    68.97 |  0.170778 |  5.09226 |
# | IDSDopt  |          99.9966 |         81.0314 |      878.52 |    18.63 |  0.181558 | 19.1508  |
# | aIDSD    |          99.992  |         81.0516 |     1032.4  |    52.24 |  0.135308 | 36.5858  |
# | dcIDSD   |          99.9966 |         60.393  |     6404.01 |   316.07 |  0.014838 | 94.5675  |
# ...

# %%
from tabulate import tabulate
def extract_row_data( X, runtime, label ):
    return [label, np.mean(X.l),np.mean(X.t), np.mean(X.g), np.mean(X.d), np.mean(X.v-X.t), np.mean(runtime)]

row0 = extract_row_data( SD, runtimeSD, "SD")
row1 = extract_row_data( ISD, runtimeISD,"ISD" )
row2 = extract_row_data( tIDSD, runtimetIDSD, "tIDSD" )
row3 = extract_row_data( IDSD0, runtimeIDSD0, "IDSD0" )
row4 = extract_row_data( IDSD1, runtimeIDSD1, "IDSD1" )
row5 = extract_row_data( IDSD2, runtimeIDSD2, "IDSD2" )
row6 = extract_row_data( IDSD3, runtimeIDSD3, "IDSD3" )
row7 = extract_row_data( dcIDSD, runtimedcIDSD, "dcIDSD" )
#row2 = ["I-DSD",np.mean(t2), np.mean(g2), np.mean(s2), np.mean(d2), np.mean(np.abs(t2-v2))];
table = [ row0, row1, row2, row3, row4, row5, row6, row7 ] #row2
print(tabulate(table, headers = ["method","train accuracy","test accuracy","And gates","levels","overfit","time"], tablefmt="github"))
# Out:
# | method   |   train accuracy |   test accuracy |   And gates |   levels |   overfit |     time |
# |----------|------------------|-----------------|-------------|----------|-----------|----------|
# | SD       |          99.9966 |         64.9619 |     6189.64 |   140.61 |  0.144843 |  6.59064 |
# | ISD      |          99.9966 |         80.4341 |     1162.23 |    72.54 |  0.17734  |  3.32478 |
# | tIDSD    |          99.9966 |         80.9163 |      957.27 |    68.97 |  0.170778 |  5.39861 |
# | IDSD0    |          99.9966 |         81.1    |      949.91 |    68.95 |  0.161563 | 66.6578  |
# | IDSD1    |          99.9961 |         81.1381 |      956.71 |    68.58 |  0.112505 | 69.6845  |
# | IDSD2    |          99.9955 |         81.1425 |      957.2  |    68.59 |  0.115783 | 70.6983  |
# | IDSD3    |          99.9955 |         81.1425 |      957.2  |    68.59 |  0.115783 | 69.9544  |
# | dcIDSD   |          99.9966 |         60.393  |     6404.01 |   316.07 |  0.014838 | 94.5675  |

# %%
print(100*np.mean((IDSD0.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD0.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD0.d-ISD.d)/ISD.d))
# Out:
# 1.2750064077769068
# -16.477504148229084
# -9.493958047648766

# %%
print(100*np.mean((IDSD0.t-tIDSD.t)/ISD.t))
print(100*np.mean((IDSD0.g-tIDSD.g)/ISD.g))
print(100*np.mean((IDSD0.d-tIDSD.d)/ISD.d))
# Out:
# 0.3131149604098472
# -0.5850315766193184
# -0.08893280632411067

# %%
print(100*np.mean((IDSD1.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD1.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD1.d-ISD.d)/ISD.d))
# Out:
# 1.333863531620916
# -15.897275255645434
# -9.693638513014248

# %%
print(100*np.mean((IDSD2.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD2.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD2.d-ISD.d)/ISD.d))
# Out:
# 1.3421813994168288
# -15.872175750603024
# -9.672569330624311

# %%
print(100*np.mean((IDSD2.t-tIDSD.t)/ISD.t))
print(100*np.mean((IDSD2.g-tIDSD.g)/ISD.g))
print(100*np.mean((IDSD2.d-tIDSD.d)/ISD.d))
# Out:
# 0.38028995204976945
# 0.020296821006742467
# -0.26754408929965434

# %%
print((np.mean(IDSD.t)-np.mean(ISD.t))/(np.mean(ISD.t)))
print((np.mean(IDSD.g)-np.mean(ISD.g))/(np.mean(ISD.g)))
print((np.mean(IDSD.d)-np.mean(ISD.d))/(np.mean(ISD.d)))
# Out:
# 0.007426492927505222
# -0.18171102105435244
# -0.049352081610146294

# %%
print(np.mean((IDSD.t-ISD.t)/ISD.t))
print(np.mean((IDSD.g-ISD.g)/ISD.g))
print(np.mean((IDSD.d-ISD.d)/ISD.d))
# Out:
# 0.011333876558442212
# -0.16466196304262565
# -0.09437283305840785

# %%
print(np.mean((aIDSD.t-ISD.t)/ISD.t))
print(np.mean((aIDSD.g-ISD.g)/ISD.g))
print(np.mean((aIDSD.d-ISD.d)/ISD.d))
# Out:
# 0.011679538719877584
# -0.09567329438572314
# -0.08211723366850812

# %%
print(np.mean((IDSDadv.t-ISD.t)/ISD.t))
print(np.mean((IDSDadv.g-ISD.g)/ISD.g))
print(np.mean((IDSDadv.d-ISD.d)/ISD.d))
# Out:
# 0.012750064077769067
# -0.16477504148229083
# -0.09493958047648766
