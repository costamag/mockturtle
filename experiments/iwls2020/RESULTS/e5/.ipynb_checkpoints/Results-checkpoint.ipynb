# %%
import numpy as np
import matplotlib.pyplot as plt
import json

class data_storage:
    b = np.array([]);
    l = np.array([]);
    t = np.array([]);
    v = np.array([]);
    d = np.array([]);
    g = np.array([]);
    s = np.array([]);
    c = np.array([]);

def extract_data( TXTpath ):
    X = data_storage()
    Cb = 0;
    Ct = 0;
    with open(TXTpath) as f:
        line = f.readline()
        while line:
            line = f.readline()
            if( line[0:2] == ".b" ):
                Cb+=1;
                X.b = np.append(X.b, int(line[2:]))
            if( line[0:2] == ".g" ):
                X.g = np.append(X.g, int(line[3:]))        
            if( line[0:2] == ".s" ):
                X.s = np.append(X.s, int(line[3:]))
            if( line[0:2] == ".c" ):
                X.c = np.append(X.c, float(line[3:]))
            if( line[0:2] == ".d" ):
                X.d = np.append(X.d, int(line[3:]))
            if( line[0:2] == ".l" ):
                X.l = np.append(X.l,float(line[3:]))
            if( line[0:2] == ".t" ):
                Ct+=1;
                X.t = np.append(X.t,float(line[3:]))
                if( Cb != Ct ):
                    print(X.b[Cb-1])
            if( line[0:2] == ".v" ):
                X.v = np.append(X.v,float(line[3:]))
            
    return X
    


M1 = extract_data( 'mnist_sdec.txt' )
M2 = extract_data( 'mnistitsdec.txt' )
M3 = extract_data( 'mnistforest5.txt' )


f = open ('mnist_sdec.json', "r")
M1j = json.loads(f.read())

f = open ('mnistitsdec.json', "r")
M2j = json.loads(f.read())

f = open ('mnistforest5.json', "r")
M3j = json.loads(f.read())


M1r = [M1j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
M2r = [M2j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
M3r = [M3j[0]["entries"][j]["runtime"] for j in range(0,99,1)]


#runtimetIDSD = [tIDSDjson[0]["entries"][j]["runtime"] for j in range(0,99,1)]

# %%
#import matplotlib.font_manager

fig = plt.figure(figsize=(16,7))
ax = plt.gca()
plt.xticks(range(0,100,5), fontsize=50)
for b in range(0,100,1):
    plt.axvline(x=b, color='k', alpha = 0.3)
for b in range(0,100,5):
    plt.axvline(x=b, color='k', alpha = 0.5)
plt.grid()
#lineSD, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#lineISD, = ax.plot(ISD.b, ISD.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
#lineIDSD, = ax.plot(IDSD.b, IDSD.t, 'o', c='white', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
#linearMUESLI, = ax.plot(arMUESLI.b, arMUESLI.t, '*', c='red', alpha=1, markeredgecolor='k', markersize = 15, label = 'arMUESLI')
#linedcIDSD, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='k', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
#lineRASS, = ax.plot(rass.b, rass.t, 'o', c='gold', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')

lineSD, = ax.plot(sdec.b, sdec.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
lineISD, = ax.plot(isdec.b, isdec.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
lineITSD, = ax.plot(itsdec.b, itsdec.t, 'o', c='white', alpha=1, markeredgecolor='k', markersize = 16, label = 'ITSD')
lineSIMMUESLI, = ax.plot(sim_muesli.b, sim_muesli.t, '*', c='gold', alpha=1, markeredgecolor='k', markersize = 16, label = 'sim_muesli')
lineARSIMMUESLI, = ax.plot(ar_sim_muesli.b, ar_sim_muesli.t, '.', c='red', alpha=1, markeredgecolor='k', markersize = 16, label = 'ar_sim_muesli')
linehdc100x10, = ax.plot(hdc100x10.b, hdc100x10.t, '.', c='k', alpha=1, markeredgecolor='k', markersize = 13, label = 'hdc100x10')
linehdc100x10S, = ax.plot(hdc100x10S.b, hdc100x10S.t, '.', c='cyan', alpha=1, markeredgecolor='k', markersize = 10, label = 'hdc100x10S')
linereservoir, = ax.plot(reservoir.b, reservoir.t, 'x', c='k', alpha=1, markeredgecolor='k', markersize = 10, label = 'reservoir')
linereservoir_assembler1, = ax.plot(reservoir_assembler1.b, reservoir_assembler1.t, 'x', c='k', alpha=1, markeredgecolor='k', markersize = 10, label = 'reservoir')
linereservoir_supp4, = ax.plot(reservoir_supp4.b, reservoir_supp4.t, 'P', c='brown', alpha=1, markeredgecolor='k', markersize = 10, label = 'reservoir')


ax.legend( handles = [lineSD, lineISD, lineITSD, lineSIMMUESLI, lineARSIMMUESLI, linehdc100x10, linehdc100x10S, linereservoir, linereservoir_assembler1, linereservoir_supp4 ], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,

plt.rcParams["font.family"] = "sans"
plt.xlabel('Benchmark', fontsize=30)
plt.ylabel('Accuracy[%]', fontsize=30)
plt.title('Test Accuracy', fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=20)
plt.savefig('acc.png')

# %%
from tabulate import tabulate
def extract_row_data( X, runtime, label ):
    return [label, np.mean(X.l),np.mean(X.t), np.mean(X.g), np.mean(X.d), np.mean(X.v-X.t), np.mean(runtime)]

rowSD = extract_row_data( SD, runtimeSD, "SD")
rowISD = extract_row_data( ISD, runtimeISD,"ISD" )
rowIDSD = extract_row_data( IDSD, runtimeIDSD, "IDSD" )
rowdcIDSD = extract_row_data( dcIDSD, runtimedcIDSD,"dcIDSD" )
rowarMUESLI = extract_row_data( arMUESLI, runtimedcIDSD,"arMUESLI" )
rowRASS = extract_row_data( rass, runtimedcIDSD,"rass" )
rowSDEC = extract_row_data( sdec, runtimeSDEC,"sdec" )
rowISDEC = extract_row_data( isdec, runtimeISDEC,"isdec" )
rowITSDEC = extract_row_data( itsdec, runtimeITSDEC,"itsdec" )
rowSIMMUESLI = extract_row_data( sim_muesli, runtimeSIMMUESLI,"simmuesli" )
rowARSIMMUESLI = extract_row_data( ar_sim_muesli, runtimeARSIMMUESLI,"ar-simmuesli" )
rowhdc100x10 = extract_row_data( hdc100x10, runtimehdc100x10,"hdc100x10" )
rowhdc100x10S = extract_row_data( hdc100x10S, runtimehdc100x10S,"hdc100x10S" )
rowreservoir = extract_row_data( reservoir, runtimereservoir,"reservoir" )
rowreservoir_assembler1 = extract_row_data( reservoir_assembler1, runtimereservoir_assembler1 ,"reservoir_ass" )
rowreservoir_supp4 = extract_row_data( reservoir_supp4, runtimereservoir_supp4 ,"reservoir_supp4" )
rowitsdec_l = extract_row_data( itsdec_l, runtimeITSDECL ,"reservoir_supp4" )
rowhdc1024x1 = extract_row_data( hdc1024x1, runtimehdc1024x1 ,"hdc1024x1" )

#row5 = extract_row_data( dcIDSD, runtimedcIDSD, "dcIDSD" )

#row2 = ["I-DSD",np.mean(t2), np.mean(g2), np.mean(s2), np.mean(d2), np.mean(np.abs(t2-v2))];
table = [ rowSD, rowISD, rowIDSD, rowdcIDSD,rowarMUESLI, rowRASS, rowSDEC, rowISDEC, rowITSDEC, rowSIMMUESLI, 
         rowARSIMMUESLI,rowhdc100x10,rowhdc100x10S, rowreservoir, rowreservoir_assembler1, rowreservoir_supp4,rowitsdec_l,rowhdc1024x1 ] #row2
print(tabulate(table, headers = ["method","train accuracy","test accuracy","And gates","levels","overfit","time"], tablefmt="github"))
# Out:
# | method          |   train accuracy |   test accuracy |   And gates |   levels |    overfit |       time |
# |-----------------|------------------|-----------------|-------------|----------|------------|------------|
# | SD              |          99.9966 |         64.9619 |     6189.64 |   140.61 |  0.144843  |    6.54338 |
# | ISD             |          99.9966 |         80.4341 |     1162.23 |    72.54 |  0.17734   |    3.36488 |
# | IDSD            |          99.9953 |         81.1436 |      958.19 |    68.58 |  0.111403  |   73.0732  |
# | dcIDSD          |          99.9966 |         60.392  |     6405.97 |   316.39 |  0.015776  |   84.0452  |
# | arMUESLI        |          99.9964 |         81.262  |      845.6  |    33.76 |  0.076557  |   84.0452  |
# | rass            |          99.9964 |         80.2861 |     1048.64 |    39.85 | -0.040309  |   84.0452  |
# | sdec            |          99.9964 |         68.5792 |     2273.54 |    90.66 |  0.017197  |   41.6782  |
# | isdec           |          99.9964 |         80.5448 |     1028.05 |    28.91 |  0.113436  |   41.6782  |
# | itsdec          |          99.9964 |         81.0447 |      840.38 |    25.52 |  0.098592  |   41.6782  |
# | simmuesli       |          68.2047 |         68.1562 |       52.33 |    23.87 |  0.0418813 |   41.6782  |
# | ar-simmuesli    |          99.9964 |         81.5328 |      867.4  |    47.27 |  0.006093  |  273.472   |
# | hdc100x10       |          99.9964 |         80.5058 |     3904.9  |    35.87 |  0.087189  |   75.6182  |
# | hdc100x10S      |          99.9964 |         80.9869 |     3799.43 |    35.55 | -0.000471  |   85.709   |
# | reservoir       |          99.9964 |         82.2195 |     1105.12 |    29.43 | -0.120623  |   41.6782  |
# | reservoir_ass   |          99.9963 |         82.6517 |     1707.04 |    31.58 |  0.018593  | 2201.42    |
# | reservoir_supp4 |          99.9964 |         81.5838 |     1918.69 |    30.01 | -0.118593  |  244.472   |
# | reservoir_supp4 |          99.9952 |         82.3489 |     1545.99 |    29.52 | 17.6453    |   41.6782  |
# | hdc1024x1       |          99.9944 |         82.4139 |     1534.48 |    33.19 | 17.5789    |  402.773   |

# %%
print(100*np.mean((IDSD.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD.d-ISD.d)/ISD.d))
# Out:
# 1.3438866176528004
# -15.812441610942141
# -9.662106635523488

# %%
print(100*np.mean((arMUESLI.t-ISD.t)/ISD.t))
print(100*np.mean((arMUESLI.g-ISD.g)/ISD.g))
print(100*np.mean((arMUESLI.d-ISD.d)/ISD.d))
# Out:
# 1.4813080256998274
# -20.79453828276973
# 13.85298390060618

# %%
print(100*np.mean((IDSD0.t-tIDSD.t)/ISD.t))
print(100*np.mean((IDSD0.g-tIDSD.g)/ISD.g))
print(100*np.mean((IDSD0.d-tIDSD.d)/ISD.d))
# Out:
# 0.3131149604098472
# -0.5850315766193184
# -0.08893280632411067

# %%
print(100*np.mean((IDSD1.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD1.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD1.d-ISD.d)/ISD.d))
# Out:
# 1.333863531620916
# -15.897275255645434
# -9.693638513014248

# %%
print(100*np.mean((IDSD2.t-ISD.t)/ISD.t))
print(100*np.mean((IDSD2.g-ISD.g)/ISD.g))
print(100*np.mean((IDSD2.d-ISD.d)/ISD.d))
# Out:
# 1.3421813994168288
# -15.872175750603024
# -9.672569330624311

# %%
print(100*np.mean((IDSD2.t-tIDSD.t)/ISD.t))
print(100*np.mean((IDSD2.g-tIDSD.g)/ISD.g))
print(100*np.mean((IDSD2.d-tIDSD.d)/ISD.d))
# Out:
# 0.38028995204976945
# 0.020296821006742467
# -0.26754408929965434

# %%
print((np.mean(IDSD.t)-np.mean(ISD.t))/(np.mean(ISD.t)))
print((np.mean(IDSD.g)-np.mean(ISD.g))/(np.mean(ISD.g)))
print((np.mean(IDSD.d)-np.mean(ISD.d))/(np.mean(ISD.d)))
# Out:
# 0.007426492927505222
# -0.18171102105435244
# -0.049352081610146294

# %%
print(np.mean((IDSD.t-ISD.t)/ISD.t))
print(np.mean((IDSD.g-ISD.g)/ISD.g))
print(np.mean((IDSD.d-ISD.d)/ISD.d))
# Out:
# 0.011333876558442212
# -0.16466196304262565
# -0.09437283305840785

# %%
print(np.mean((aIDSD.t-ISD.t)/ISD.t))
print(np.mean((aIDSD.g-ISD.g)/ISD.g))
print(np.mean((aIDSD.d-ISD.d)/ISD.d))
# Out:
# 0.011679538719877584
# -0.09567329438572314
# -0.08211723366850812

# %%
print(np.mean((IDSDadv.t-ISD.t)/ISD.t))
print(np.mean((IDSDadv.g-ISD.g)/ISD.g))
print(np.mean((IDSDadv.d-ISD.d)/ISD.d))
# Out:
# 0.012750064077769067
# -0.16477504148229083
# -0.09493958047648766

# %%
IDSD.g
# Out:
# array([1767.,  164., 1974.,  143., 1742.,  136., 1491.,  138., 1354.,
#         139.,  761.,  636.,  617.,  574.,  460.,  519.,  444.,  393.,
#         369.,  350., 4760.,  571., 2430.,  878., 2009., 1678., 1751.,
#        1504., 1527., 1357.,  156.,  160.,  157.,  149.,  149.,  145.,
#         139.,  152.,  142.,  138., 1737.,  130., 2430., 1911., 2020.,
#        2462., 1722., 2030., 1469., 1702.,  372., 1526., 1453.,  872.,
#         302.,  171.,  158.,  122.,  220.,  227.,  428.,   44.,  320.,
#          98.,    7.,  101.,  436.,  423.,  175.,  147.,  160.,  139.,
#         224., 1215.,   45., 1936., 2030., 1985., 5165., 1985.,  646.,
#         475.,  355.,  278.,  350.,  341.,  320.,  333.,  391.,  365.,
#        2120., 1254., 2625., 2483., 2052.,  865., 1950., 2008., 1201.,
#        1185.])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

P0=0.5
PX0 = 0.5

# Make data.
X = np.arange(0.0001, 1, 0.0001)
Y = np.arange(0.0001, 1, 0.0001)
X, Y = np.meshgrid(X, Y)
Z = (P0==(PX0*X+(1-PX0)*Y))*(PX0*X*np.log2((X/P0))+PX0*(1-X)*np.log2(((1-X)/(1-P0)))+(1-PX0)*Y*np.log2((Y/P0))+(1-PX0)*(1-Y)*np.log2(((1-Y)/(1-P0))))


# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

#surf = ax.plot_surface(X, Y, C, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_xlabel('$p0|0$')
ax.set_ylabel('$p0|1$')

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.6, aspect=6)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

P0=0.8
PX0 = 0.5

# Make data.
X = np.arange(0.001, 1, 0.0005)
Y = np.arange(0.001, 1, 0.0005)
X, Y = np.meshgrid(X, Y)
Z = (P0==(PX0*X+(1-PX0)*Y))*(PX0*X*np.log2((X/P0))+PX0*(1-X)*np.log2(((1-X)/(1-P0)))+(1-PX0)*Y*np.log2((Y/P0))+(1-PX0)*(1-Y)*np.log2(((1-Y)/(1-P0))))

print(np.amax(Z))
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

#surf = ax.plot_surface(X, Y, C, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-3, 3)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_xlabel('$p^{F|X}_{0|0}$')
ax.set_ylabel('$p^{F|X}_{0|1}$')
ax.set_title('$I(p^{F|X}_{0|0},p^{F|X}_{0|1};p^{F}_{0}=0.5,p^{X}_{0}=0.5)$')

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.6, aspect=6)

plt.show()
# Out:
# 0.2334973843913831

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

P0=0.5
PX0 = 0.4

# Make data.
X = np.arange(0.001, 1, 0.0005)
Y = np.arange(0.001, 1, 0.0005)
X, Y = np.meshgrid(X, Y)
Z = (P0==(PX0*X+(1-PX0)*Y))*(PX0*X*np.log2((X/P0))+PX0*(1-X)*np.log2(((1-X)/(1-P0)))+(1-PX0)*Y*np.log2((Y/P0))+(1-PX0)*(1-Y)*np.log2(((1-Y)/(1-P0))))


# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

#surf = ax.plot_surface(X, Y, C, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-3, 3)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_xlabel('$p^{F|X}_{0|0}$')
ax.set_ylabel('$p^{F|X}_{0|1}$')
ax.set_title('$I(p^{F|X}_{0|0},p^{F|X}_{0|1};p^{F}_{0}=0.5,p^{X}_{0}=0.4)$')

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.6, aspect=6)

plt.show()
