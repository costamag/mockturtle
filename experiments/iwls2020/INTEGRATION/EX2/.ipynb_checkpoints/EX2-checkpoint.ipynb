# %% [markdown]
# # Experiment 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import json

class data_storage:
    b = np.array([]);
    l = np.array([]);
    t = np.array([]);
    v = np.array([]);
    d = np.array([]);
    g = np.array([]);
    s = np.array([]);
    c = np.array([]);

def extract_data( TXTpath ):
    X = data_storage()
    Cb = 0;
    Ct = 0;
    with open(TXTpath) as f:
        line = f.readline()
        while line:
            line = f.readline()
            if( line[0:2] == ".b" ):
                Cb+=1;
                X.b = np.append(X.b, int(line[2:]))
            if( line[0:2] == ".g" ):
                X.g = np.append(X.g, int(line[3:]))        
            if( line[0:2] == ".s" ):
                X.s = np.append(X.s, int(line[3:]))
            if( line[0:2] == ".c" ):
                X.c = np.append(X.c, float(line[3:]))
            if( line[0:2] == ".d" ):
                X.d = np.append(X.d, int(line[3:]))
            if( line[0:2] == ".l" ):
                X.l = np.append(X.l,float(line[3:]))
            if( line[0:2] == ".t" ):
                Ct+=1;
                X.t = np.append(X.t,float(line[3:]))
                if( Cb != Ct ):
                    print(X.b[Cb-1])
            if( line[0:2] == ".v" ):
                X.v = np.append(X.v,float(line[3:]))
            
    return X
    
D0 = extract_data( 'DK_XTSD/RES/summary.txt' )
D1 = extract_data( 'DC_IXTSD/RES/summary.txt' )
#D2 = extract_data( 'DK_TSD/RES/summary.txt' )
##D3 = extract_data( 'DK_XTSD/RES/summary.txt' )
#D4 = extract_data( 'DK_DSD/RES/summary.txt' )
#D5 = extract_data( 'DK_RDSD/RES/summary.txt' )
#D4 = extract_data( 'dcsdec/RES/summary.txt' )D5 = extract_data( 'dcxsdec/RES/summary.txt' )
#D6 = extract_data( 'idsdS0d001/RES/summary.txt' )
#D7 = extract_data( 'idsdS0d1/RES/summary.txt' )
#D7 = extract_data( 'idsdS/RES/summary.txt' )
#D8 = extract_data( 'iedsdS/RES/summary.txt' )

f = open ('DK_XTSD.json', "r")
D0j = json.loads(f.read())

f = open ('DC_IXTSD.json', "r")
D1j = json.loads(f.read())

#f = open ('DK_TSD.json', "r")
#D2j = json.loads(f.read())

#f = open ('DK_XTSD.json', "r")
#D3j = json.loads(f.read())

#f = open ('DK_DSD.json', "r")
#D4j = json.loads(f.read())

#f = open ('DK_RDSD.json', "r")
#D5j = json.loads(f.read())

D0r = [D0j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
D1r = [D1j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#D2r = [D2j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#D3r = [D3j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#D4r = [D4j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#D5r = [D5j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [2], line 76
#      62 D1j = json.loads(f.read())
#      64 #f = open ('DK_TSD.json', "r")
#      65 #D2j = json.loads(f.read())
#      66
#    (...)
#      73 #f = open ('DK_RDSD.json', "r")
#      74 #D5j = json.loads(f.read())
# ---> 76 D0r = [D0j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      77 D1r = [D1j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      78 #D2r = [D2j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      79 #D3r = [D3j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      80 #D4r = [D4j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      81 #D5r = [D5j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#
# Cell In [2], line 76, in <listcomp>(.0)
#      62 D1j = json.loads(f.read())
#      64 #f = open ('DK_TSD.json', "r")
#      65 #D2j = json.loads(f.read())
#      66
#    (...)
#      73 #f = open ('DK_RDSD.json', "r")
#      74 #D5j = json.loads(f.read())
# ---> 76 D0r = [D0j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      77 D1r = [D1j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      78 #D2r = [D2j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      79 #D3r = [D3j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      80 #D4r = [D4j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#      81 #D5r = [D5j[0]["entries"][j]["runtime"] for j in range(0,99,1)]
#
# IndexError: list index out of range

# %%
#import matplotlib.font_manager

fig = plt.figure(figsize=(16,7))
ax = plt.gca()
plt.xticks(range(0,100,5), fontsize=50)
for b in range(0,100,1):
    plt.axvline(x=b, color='k', alpha = 0.3)
for b in range(0,100,5):
    plt.axvline(x=b, color='k', alpha = 0.5)
plt.grid()
#lineSD, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#lineISD, = ax.plot(ISD.b, ISD.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
#lineIDSD, = ax.plot(IDSD.b, IDSD.t, 'o', c='white', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
#linearMUESLI, = ax.plot(arMUESLI.b, arMUESLI.t, '*', c='red', alpha=1, markeredgecolor='k', markersize = 15, label = 'arMUESLI')
#linedcIDSD, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='k', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
#lineRASS, = ax.plot(rass.b, rass.t, 'o', c='gold', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')

#line0, = ax.plot(D0.b, D0.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#line1, = ax.plot(D2.b, D2.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ITSD')
#line2, = ax.plot(D3.b, D2.t , 'v', c='white', alpha=1, markeredgecolor='k', markersize = 16 , label = 'ITSD')
line3, = ax.plot(D3.b, D3.t , 'v', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IXTSD')
#line4, = ax.plot(D4.b, D4.t , 'x', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IDSDp')
line8, = ax.plot(D8.b, D8.t , 'x', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IDSD')

ax.legend( handles = [ line3,line8 ], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,

plt.rcParams["font.family"] = "sans"
plt.xlabel('Benchmark', fontsize=30)
plt.ylabel('Accuracy[%]', fontsize=30)
plt.title('Test Accuracy', fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=20)
plt.savefig('acc.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 23
#      21 line3, = ax.plot(D3.b, D3.t , 'v', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IXTSD')
#      22 #line4, = ax.plot(D4.b, D4.t , 'x', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IDSDp')
# ---> 23 line8, = ax.plot(D8.b, D8.t , 'x', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IDSD')
#      25 ax.legend( handles = [ line3,line8 ], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,
#      27 plt.rcParams["font.family"] = "sans"
#
# NameError: name 'D8' is not defined

# %%
from tabulate import tabulate
def extract_row_data( X, runtime, label ):
    return [label, np.mean(X.l),np.mean(X.t), np.mean(X.g), np.mean(X.d), np.mean(X.v-X.t), np.mean(runtime)]

row0 = extract_row_data( D0, D0r, "SD")
row1 = extract_row_data( D1, D1r, "DK-SD")
row2 = extract_row_data( D2, D2r, "DK-TSD")
row3 = extract_row_data( D3, D3r, "DK-XTSD")
row4 = extract_row_data( D4, D4r, "DK-DSD")
row5 = extract_row_data( D5, D5r, "IDSD.01")
#row6 = extract_row_data( D6, D6r, "IDSD.001")
#row7 = extract_row_data( D7, D7r, "IDSD")
#row8 = extract_row_data( D8, D8r, "IEDSD")

#row5 = extract_row_data( dcIDSD, runtimedcIDSD, "dcIDSD" )

#row2 = ["I-DSD",np.mean(t2), np.mean(g2), np.mean(s2), np.mean(d2), np.mean(np.abs(t2-v2))];
table = [ row0, row1, row2, row3, row4, row5 ]#row4, row5, row6, row7, row8 ] #row2
print(tabulate(table, headers = ["method","train accuracy[%]","test accuracy[%]","And gates","levels","overfit[%]","time[s]"], tablefmt="github"))
# Out:
# | method   |   train accuracy[%] |   test accuracy[%] |   And gates |   levels |   overfit[%] |   time[s] |
# |----------|---------------------|--------------------|-------------|----------|--------------|-----------|
# | SD       |             99.9964 |            68.5766 |     2274.08 |    90.66 |     0.016884 |  1.21282  |
# | DK-SD    |             99.9964 |            80.543  |     1027.74 |    29.16 |     0.115624 |  1.0527   |
# | DK-TSD   |             99.9964 |            80.543  |      873.51 |    25.48 |     0.115624 |  0.946576 |
# | DK-XTSD  |             99.9964 |            81.0433 |      836.95 |    25.4  |     0.101249 |  1.4681   |
# | DK-DSD   |             99.9963 |            81.0945 |      831.53 |    25.12 |     0.066243 | 12.2575   |
# | IDSD.01  |             99.9963 |            83.0692 |      731.32 |    27.9  |     0.055    | 40.9182   |

# %%
print(np.mean((D4.t-D1.t)/D1.t))
print(np.mean((D4.d-D1.d)/D1.d))
print(np.mean((D4.g-D1.g)/D1.g))
# Out:
# 0.011164758714160526
# -0.12027950318533166
# -0.1738352600928506

# %%
#import matplotlib.font_manager

fig = plt.figure(figsize=(16,7))
ax = plt.gca()
plt.xticks(range(0,100,5), fontsize=50)
for b in range(0,100,1):
    plt.axvline(x=b, color='k', alpha = 0.3)
for b in range(0,100,5):
    plt.axvline(x=b, color='k', alpha = 0.5)
plt.grid()
#lineSD, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#lineISD, = ax.plot(ISD.b, ISD.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
#lineIDSD, = ax.plot(IDSD.b, IDSD.t, 'o', c='white', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
#linearMUESLI, = ax.plot(arMUESLI.b, arMUESLI.t, '*', c='red', alpha=1, markeredgecolor='k', markersize = 15, label = 'arMUESLI')
#linedcIDSD, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='k', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
#lineRASS, = ax.plot(rass.b, rass.t, 'o', c='gold', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')

line0, = ax.plot(D0.b, D0.t , 's', c='blue', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
line1, = ax.plot(D4.b, D4.t , 'D', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 18 , label = 'DCTSD')
line2, = ax.plot(D5.b, D5.t , 'v', c='cyan', alpha=1, markeredgecolor='k', markersize = 16 , label = 'DCXTSD')
line3, = ax.plot(D2.b, D2.t , 'o', c='gold', alpha=1, markeredgecolor='k', markersize = 16 , label = 'ITSD')
line4, = ax.plot(D3.b, D3.t , '*', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IXTSD')
#line6, = ax.plot(D6.b, D3.t , '*', c='red', alpha=1, markeredgecolor='k', markersize = 14 , label = 'IXTSD')

ax.legend( handles = [line0, line1, line2, line3, line4 ], fontsize=15, bbox_to_anchor=(0.09, 0.75, 0.04, .102)) #,

plt.rcParams["font.family"] = "sans"
plt.xlabel('Benchmark', fontsize=30)
plt.ylabel('Accuracy[%]', fontsize=30)
plt.title('Test Accuracy', fontsize=40)
ax.tick_params(axis='both', which='major', labelsize=20)
plt.savefig('acc.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [29], line 18
#      10 plt.grid()
#      11 #lineSD, = ax.plot(SD.b, SD.t , 's', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#      12 #lineISD, = ax.plot(ISD.b, ISD.t , 'D', c='blue', alpha=1, markeredgecolor='k', markersize = 18 , label = 'ISD')
#      13 #lineIDSD, = ax.plot(IDSD.b, IDSD.t, 'o', c='white', alpha=1, markeredgecolor='k', markersize = 16, label = 'IDSD')
#      14 #linearMUESLI, = ax.plot(arMUESLI.b, arMUESLI.t, '*', c='red', alpha=1, markeredgecolor='k', markersize = 15, label = 'arMUESLI')
#      15 #linedcIDSD, = ax.plot(dcIDSD.b, dcIDSD.t, 'P', c='k', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
#      16 #lineRASS, = ax.plot(rass.b, rass.t, 'o', c='gold', alpha=1, markeredgecolor='k', markersize = 11, label = 'dcDSD')
# ---> 18 line0, = ax.plot(D0.b, D0.t , 's', c='blue', alpha=1, markeredgecolor='k', markersize = 20, label = 'SD')
#      19 line1, = ax.plot(D4.b, D4.t , 'D', c='#0aff02', alpha=1, markeredgecolor='k', markersize = 18 , label = 'DCTSD')
#      20 line2, = ax.plot(D5.b, D5.t , 'v', c='cyan', alpha=1, markeredgecolor='k', markersize = 16 , label = 'DCXTSD')
#
# NameError: name 'D0' is not defined

# %% [markdown]
# # Experiment 2
